# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from imblearn.over_sampling import SMOTE
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("encoded_clean_clinical_wav2vec2.csv")

# %%
df.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 1 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 2 -0.036963  0.027261 -0.097449 -0.025534 -0.055059 -0.135565  0.002773
# 3 -0.066899  0.018125 -0.133178 -0.038802 -0.032812 -0.119408 -0.008754
# 4 -0.032680  0.024876 -0.140349 -0.030479  0.017331 -0.111734 -0.022145
#
#      feat_7    feat_8    feat_9  ...  tb_prior  tb_prior_Pul  hemoptysis  \
# 0 -0.000749 -0.034801 -0.417850  ...         0             0           0
# 1 -0.004235 -0.051047 -0.439018  ...         0             0           0
# 2 -0.035429 -0.032010 -0.351857  ...         0             0           0
# 3 -0.031919 -0.104976 -0.353431  ...         0             0           0
# 4 -0.028799 -0.051605 -0.321307  ...         0             0           0
#
#    heart_rate  temperature  weight_loss  smoke_lweek  fever  night_sweats  \
# 0          68         37.5            1            0      1             1
# 1          68         37.5            1            0      1             1
# 2          76         37.7            1            1      1             1
# 3          76         37.7            1            1      1             1
# 4          76         37.7            1            1      1             1
#
#    tb_status
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 783 columns]

# %%
df['tb_status'].value_counts()
# Out:
# tb_status
# 1    4900
# 0     289
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (5189, 783)

# %%
df.columns
# Out:
# Index(['feat_0', 'feat_1', 'feat_2', 'feat_3', 'feat_4', 'feat_5', 'feat_6',
#        'feat_7', 'feat_8', 'feat_9',
#        ...
#        'tb_prior', 'tb_prior_Pul', 'hemoptysis', 'heart_rate', 'temperature',
#        'weight_loss', 'smoke_lweek', 'fever', 'night_sweats', 'tb_status'],
#       dtype='object', length=783)

# %%
print(y.value_counts())
# Out:
# tb_status
# 1    4900
# 0     289
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# feat_0                float64
# feat_1                float64
# feat_2                float64
# feat_3                float64
# feat_4                float64
# feat_5                float64
# feat_6                float64
# feat_7                float64
# feat_8                float64
# feat_9                float64
# feat_10               float64
# feat_11               float64
# feat_12               float64
# feat_13               float64
# feat_14               float64
# feat_15               float64
# feat_16               float64
# feat_17               float64
# feat_18               float64
# feat_19               float64
# feat_20               float64
# feat_21               float64
# feat_22               float64
# feat_23               float64
# feat_24               float64
# feat_25               float64
# feat_26               float64
# feat_27               float64
# feat_28               float64
# feat_29               float64
# feat_30               float64
# feat_31               float64
# feat_32               float64
# feat_33               float64
# feat_34               float64
# feat_35               float64
# feat_36               float64
# feat_37               float64
# feat_38               float64
# feat_39               float64
# feat_40               float64
# feat_41               float64
# feat_42               float64
# feat_43               float64
# feat_44               float64
# feat_45               float64
# feat_46               float64
# feat_47               float64
# feat_48               float64
# feat_49               float64
# feat_50               float64
# feat_51               float64
# feat_52               float64
# feat_53               float64
# feat_54               float64
# feat_55               float64
# feat_56               float64
# feat_57               float64
# feat_58               float64
# feat_59               float64
# feat_60               float64
# feat_61               float64
# feat_62               float64
# feat_63               float64
# feat_64               float64
# feat_65               float64
# feat_66               float64
# feat_67               float64
# feat_68               float64
# feat_69               float64
# feat_70               float64
# feat_71               float64
# feat_72               float64
# feat_73               float64
# feat_74               float64
# feat_75               float64
# feat_76               float64
# feat_77               float64
# feat_78               float64
# feat_79               float64
# feat_80               float64
# feat_81               float64
# feat_82               float64
# feat_83               float64
# feat_84               float64
# feat_85               float64
# feat_86               float64
# feat_87               float64
# feat_88               float64
# feat_89               float64
# feat_90               float64
# feat_91               float64
# feat_92               float64
# feat_93               float64
# feat_94               float64
# feat_95               float64
# feat_96               float64
# feat_97               float64
# feat_98               float64
# feat_99               float64
# feat_100              float64
# feat_101              float64
# feat_102              float64
# feat_103              float64
# feat_104              float64
# feat_105              float64
# feat_106              float64
# feat_107              float64
# feat_108              float64
# feat_109              float64
# feat_110              float64
# feat_111              float64
# feat_112              float64
# feat_113              float64
# feat_114              float64
# feat_115              float64
# feat_116              float64
# feat_117              float64
# feat_118              float64
# feat_119              float64
# feat_120              float64
# feat_121              float64
# feat_122              float64
# feat_123              float64
# feat_124              float64
# feat_125              float64
# feat_126              float64
# feat_127              float64
# feat_128              float64
# feat_129              float64
# feat_130              float64
# feat_131              float64
# feat_132              float64
# feat_133              float64
# feat_134              float64
# feat_135              float64
# feat_136              float64
# feat_137              float64
# feat_138              float64
# feat_139              float64
# feat_140              float64
# feat_141              float64
# feat_142              float64
# feat_143              float64
# feat_144              float64
# feat_145              float64
# feat_146              float64
# feat_147              float64
# feat_148              float64
# feat_149              float64
# feat_150              float64
# feat_151              float64
# feat_152              float64
# feat_153              float64
# feat_154              float64
# feat_155              float64
# feat_156              float64
# feat_157              float64
# feat_158              float64
# feat_159              float64
# feat_160              float64
# feat_161              float64
# feat_162              float64
# feat_163              float64
# feat_164              float64
# feat_165              float64
# feat_166              float64
# feat_167              float64
# feat_168              float64
# feat_169              float64
# feat_170              float64
# feat_171              float64
# feat_172              float64
# feat_173              float64
# feat_174              float64
# feat_175              float64
# feat_176              float64
# feat_177              float64
# feat_178              float64
# feat_179              float64
# feat_180              float64
# feat_181              float64
# feat_182              float64
# feat_183              float64
# feat_184              float64
# feat_185              float64
# feat_186              float64
# feat_187              float64
# feat_188              float64
# feat_189              float64
# feat_190              float64
# feat_191              float64
# feat_192              float64
# feat_193              float64
# feat_194              float64
# feat_195              float64
# feat_196              float64
# feat_197              float64
# feat_198              float64
# feat_199              float64
# feat_200              float64
# feat_201              float64
# feat_202              float64
# feat_203              float64
# feat_204              float64
# feat_205              float64
# feat_206              float64
# feat_207              float64
# feat_208              float64
# feat_209              float64
# feat_210              float64
# feat_211              float64
# feat_212              float64
# feat_213              float64
# feat_214              float64
# feat_215              float64
# feat_216              float64
# feat_217              float64
# feat_218              float64
# feat_219              float64
# feat_220              float64
# feat_221              float64
# feat_222              float64
# feat_223              float64
# feat_224              float64
# feat_225              float64
# feat_226              float64
# feat_227              float64
# feat_228              float64
# feat_229              float64
# feat_230              float64
# feat_231              float64
# feat_232              float64
# feat_233              float64
# feat_234              float64
# feat_235              float64
# feat_236              float64
# feat_237              float64
# feat_238              float64
# feat_239              float64
# feat_240              float64
# feat_241              float64
# feat_242              float64
# feat_243              float64
# feat_244              float64
# feat_245              float64
# feat_246              float64
# feat_247              float64
# feat_248              float64
# feat_249              float64
# feat_250              float64
# feat_251              float64
# feat_252              float64
# feat_253              float64
# feat_254              float64
# feat_255              float64
# feat_256              float64
# feat_257              float64
# feat_258              float64
# feat_259              float64
# feat_260              float64
# feat_261              float64
# feat_262              float64
# feat_263              float64
# feat_264              float64
# feat_265              float64
# feat_266              float64
# feat_267              float64
# feat_268              float64
# feat_269              float64
# feat_270              float64
# feat_271              float64
# feat_272              float64
# feat_273              float64
# feat_274              float64
# feat_275              float64
# feat_276              float64
# feat_277              float64
# feat_278              float64
# feat_279              float64
# feat_280              float64
# feat_281              float64
# feat_282              float64
# feat_283              float64
# feat_284              float64
# feat_285              float64
# feat_286              float64
# feat_287              float64
# feat_288              float64
# feat_289              float64
# feat_290              float64
# feat_291              float64
# feat_292              float64
# feat_293              float64
# feat_294              float64
# feat_295              float64
# feat_296              float64
# feat_297              float64
# feat_298              float64
# feat_299              float64
# feat_300              float64
# feat_301              float64
# feat_302              float64
# feat_303              float64
# feat_304              float64
# feat_305              float64
# feat_306              float64
# feat_307              float64
# feat_308              float64
# feat_309              float64
# feat_310              float64
# feat_311              float64
# feat_312              float64
# feat_313              float64
# feat_314              float64
# feat_315              float64
# feat_316              float64
# feat_317              float64
# feat_318              float64
# feat_319              float64
# feat_320              float64
# feat_321              float64
# feat_322              float64
# feat_323              float64
# feat_324              float64
# feat_325              float64
# feat_326              float64
# feat_327              float64
# feat_328              float64
# feat_329              float64
# feat_330              float64
# feat_331              float64
# feat_332              float64
# feat_333              float64
# feat_334              float64
# feat_335              float64
# feat_336              float64
# feat_337              float64
# feat_338              float64
# feat_339              float64
# feat_340              float64
# feat_341              float64
# feat_342              float64
# feat_343              float64
# feat_344              float64
# feat_345              float64
# feat_346              float64
# feat_347              float64
# feat_348              float64
# feat_349              float64
# feat_350              float64
# feat_351              float64
# feat_352              float64
# feat_353              float64
# feat_354              float64
# feat_355              float64
# feat_356              float64
# feat_357              float64
# feat_358              float64
# feat_359              float64
# feat_360              float64
# feat_361              float64
# feat_362              float64
# feat_363              float64
# feat_364              float64
# feat_365              float64
# feat_366              float64
# feat_367              float64
# feat_368              float64
# feat_369              float64
# feat_370              float64
# feat_371              float64
# feat_372              float64
# feat_373              float64
# feat_374              float64
# feat_375              float64
# feat_376              float64
# feat_377              float64
# feat_378              float64
# feat_379              float64
# feat_380              float64
# feat_381              float64
# feat_382              float64
# feat_383              float64
# feat_384              float64
# feat_385              float64
# feat_386              float64
# feat_387              float64
# feat_388              float64
# feat_389              float64
# feat_390              float64
# feat_391              float64
# feat_392              float64
# feat_393              float64
# feat_394              float64
# feat_395              float64
# feat_396              float64
# feat_397              float64
# feat_398              float64
# feat_399              float64
# feat_400              float64
# feat_401              float64
# feat_402              float64
# feat_403              float64
# feat_404              float64
# feat_405              float64
# feat_406              float64
# feat_407              float64
# feat_408              float64
# feat_409              float64
# feat_410              float64
# feat_411              float64
# feat_412              float64
# feat_413              float64
# feat_414              float64
# feat_415              float64
# feat_416              float64
# feat_417              float64
# feat_418              float64
# feat_419              float64
# feat_420              float64
# feat_421              float64
# feat_422              float64
# feat_423              float64
# feat_424              float64
# feat_425              float64
# feat_426              float64
# feat_427              float64
# feat_428              float64
# feat_429              float64
# feat_430              float64
# feat_431              float64
# feat_432              float64
# feat_433              float64
# feat_434              float64
# feat_435              float64
# feat_436              float64
# feat_437              float64
# feat_438              float64
# feat_439              float64
# feat_440              float64
# feat_441              float64
# feat_442              float64
# feat_443              float64
# feat_444              float64
# feat_445              float64
# feat_446              float64
# feat_447              float64
# feat_448              float64
# feat_449              float64
# feat_450              float64
# feat_451              float64
# feat_452              float64
# feat_453              float64
# feat_454              float64
# feat_455              float64
# feat_456              float64
# feat_457              float64
# feat_458              float64
# feat_459              float64
# feat_460              float64
# feat_461              float64
# feat_462              float64
# feat_463              float64
# feat_464              float64
# feat_465              float64
# feat_466              float64
# feat_467              float64
# feat_468              float64
# feat_469              float64
# feat_470              float64
# feat_471              float64
# feat_472              float64
# feat_473              float64
# feat_474              float64
# feat_475              float64
# feat_476              float64
# feat_477              float64
# feat_478              float64
# feat_479              float64
# feat_480              float64
# feat_481              float64
# feat_482              float64
# feat_483              float64
# feat_484              float64
# feat_485              float64
# feat_486              float64
# feat_487              float64
# feat_488              float64
# feat_489              float64
# feat_490              float64
# feat_491              float64
# feat_492              float64
# feat_493              float64
# feat_494              float64
# feat_495              float64
# feat_496              float64
# feat_497              float64
# feat_498              float64
# feat_499              float64
# feat_500              float64
# feat_501              float64
# feat_502              float64
# feat_503              float64
# feat_504              float64
# feat_505              float64
# feat_506              float64
# feat_507              float64
# feat_508              float64
# feat_509              float64
# feat_510              float64
# feat_511              float64
# feat_512              float64
# feat_513              float64
# feat_514              float64
# feat_515              float64
# feat_516              float64
# feat_517              float64
# feat_518              float64
# feat_519              float64
# feat_520              float64
# feat_521              float64
# feat_522              float64
# feat_523              float64
# feat_524              float64
# feat_525              float64
# feat_526              float64
# feat_527              float64
# feat_528              float64
# feat_529              float64
# feat_530              float64
# feat_531              float64
# feat_532              float64
# feat_533              float64
# feat_534              float64
# feat_535              float64
# feat_536              float64
# feat_537              float64
# feat_538              float64
# feat_539              float64
# feat_540              float64
# feat_541              float64
# feat_542              float64
# feat_543              float64
# feat_544              float64
# feat_545              float64
# feat_546              float64
# feat_547              float64
# feat_548              float64
# feat_549              float64
# feat_550              float64
# feat_551              float64
# feat_552              float64
# feat_553              float64
# feat_554              float64
# feat_555              float64
# feat_556              float64
# feat_557              float64
# feat_558              float64
# feat_559              float64
# feat_560              float64
# feat_561              float64
# feat_562              float64
# feat_563              float64
# feat_564              float64
# feat_565              float64
# feat_566              float64
# feat_567              float64
# feat_568              float64
# feat_569              float64
# feat_570              float64
# feat_571              float64
# feat_572              float64
# feat_573              float64
# feat_574              float64
# feat_575              float64
# feat_576              float64
# feat_577              float64
# feat_578              float64
# feat_579              float64
# feat_580              float64
# feat_581              float64
# feat_582              float64
# feat_583              float64
# feat_584              float64
# feat_585              float64
# feat_586              float64
# feat_587              float64
# feat_588              float64
# feat_589              float64
# feat_590              float64
# feat_591              float64
# feat_592              float64
# feat_593              float64
# feat_594              float64
# feat_595              float64
# feat_596              float64
# feat_597              float64
# feat_598              float64
# feat_599              float64
# feat_600              float64
# feat_601              float64
# feat_602              float64
# feat_603              float64
# feat_604              float64
# feat_605              float64
# feat_606              float64
# feat_607              float64
# feat_608              float64
# feat_609              float64
# feat_610              float64
# feat_611              float64
# feat_612              float64
# feat_613              float64
# feat_614              float64
# feat_615              float64
# feat_616              float64
# feat_617              float64
# feat_618              float64
# feat_619              float64
# feat_620              float64
# feat_621              float64
# feat_622              float64
# feat_623              float64
# feat_624              float64
# feat_625              float64
# feat_626              float64
# feat_627              float64
# feat_628              float64
# feat_629              float64
# feat_630              float64
# feat_631              float64
# feat_632              float64
# feat_633              float64
# feat_634              float64
# feat_635              float64
# feat_636              float64
# feat_637              float64
# feat_638              float64
# feat_639              float64
# feat_640              float64
# feat_641              float64
# feat_642              float64
# feat_643              float64
# feat_644              float64
# feat_645              float64
# feat_646              float64
# feat_647              float64
# feat_648              float64
# feat_649              float64
# feat_650              float64
# feat_651              float64
# feat_652              float64
# feat_653              float64
# feat_654              float64
# feat_655              float64
# feat_656              float64
# feat_657              float64
# feat_658              float64
# feat_659              float64
# feat_660              float64
# feat_661              float64
# feat_662              float64
# feat_663              float64
# feat_664              float64
# feat_665              float64
# feat_666              float64
# feat_667              float64
# feat_668              float64
# feat_669              float64
# feat_670              float64
# feat_671              float64
# feat_672              float64
# feat_673              float64
# feat_674              float64
# feat_675              float64
# feat_676              float64
# feat_677              float64
# feat_678              float64
# feat_679              float64
# feat_680              float64
# feat_681              float64
# feat_682              float64
# feat_683              float64
# feat_684              float64
# feat_685              float64
# feat_686              float64
# feat_687              float64
# feat_688              float64
# feat_689              float64
# feat_690              float64
# feat_691              float64
# feat_692              float64
# feat_693              float64
# feat_694              float64
# feat_695              float64
# feat_696              float64
# feat_697              float64
# feat_698              float64
# feat_699              float64
# feat_700              float64
# feat_701              float64
# feat_702              float64
# feat_703              float64
# feat_704              float64
# feat_705              float64
# feat_706              float64
# feat_707              float64
# feat_708              float64
# feat_709              float64
# feat_710              float64
# feat_711              float64
# feat_712              float64
# feat_713              float64
# feat_714              float64
# feat_715              float64
# feat_716              float64
# feat_717              float64
# feat_718              float64
# feat_719              float64
# feat_720              float64
# feat_721              float64
# feat_722              float64
# feat_723              float64
# feat_724              float64
# feat_725              float64
# feat_726              float64
# feat_727              float64
# feat_728              float64
# feat_729              float64
# feat_730              float64
# feat_731              float64
# feat_732              float64
# feat_733              float64
# feat_734              float64
# feat_735              float64
# feat_736              float64
# feat_737              float64
# feat_738              float64
# feat_739              float64
# feat_740              float64
# feat_741              float64
# feat_742              float64
# feat_743              float64
# feat_744              float64
# feat_745              float64
# feat_746              float64
# feat_747              float64
# feat_748              float64
# feat_749              float64
# feat_750              float64
# feat_751              float64
# feat_752              float64
# feat_753              float64
# feat_754              float64
# feat_755              float64
# feat_756              float64
# feat_757              float64
# feat_758              float64
# feat_759              float64
# feat_760              float64
# feat_761              float64
# feat_762              float64
# feat_763              float64
# feat_764              float64
# feat_765              float64
# feat_766              float64
# feat_767              float64
# sex                     int64
# age                     int64
# height                float64
# weight                float64
# reported_cough_dur      int64
# tb_prior                int64
# tb_prior_Pul            int64
# hemoptysis              int64
# heart_rate              int64
# temperature           float64
# weight_loss             int64
# smoke_lweek             int64
# fever                   int64
# night_sweats            int64
# tb_status               int64
# dtype: object

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# For reproducibility
np.random.seed(42)
torch.manual_seed(42)

# %%
X = df.drop("tb_status", axis=1)
y = df["tb_status"]

# %%
# Extract only tb-negative samples (minority)
minority_data = X[y == 0]

print("Minority class shape:", minority_data.shape)  # Should be (289, 782)

# Scale features
scaler = StandardScaler()
minority_scaled = scaler.fit_transform(minority_data)

input_dim = minority_scaled.shape[1]  # 782
print("Input dimension:", input_dim)
# Out:
# Minority class shape: (289, 782)
# Input dimension: 782

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, input_dim, noise_dim=64):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(noise_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim)
        )

    def forward(self, z):
        return self.net(z)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.net(x)

# %%
noise_dim = 64

generator = Generator(input_dim=input_dim, noise_dim=noise_dim)
discriminator = Discriminator(input_dim=input_dim)

criterion = nn.BCELoss()
g_optimizer = optim.Adam(generator.parameters(), lr=0.0002)
d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002)

# %%
# Convert scaled data to tensor
minority_tensor = torch.tensor(minority_scaled, dtype=torch.float)

epochs = 3000
batch_size = 64

for epoch in range(epochs):
    # === Train Discriminator ===
    idx = np.random.randint(0, minority_tensor.shape[0], batch_size)
    real_data = minority_tensor[idx]
    real_labels = torch.ones(batch_size, 1)

    z = torch.randn(batch_size, noise_dim)
    fake_data = generator(z).detach()
    fake_labels = torch.zeros(batch_size, 1)

    d_real = discriminator(real_data)
    d_fake = discriminator(fake_data)

    d_loss_real = criterion(d_real, real_labels)
    d_loss_fake = criterion(d_fake, fake_labels)
    d_loss = d_loss_real + d_loss_fake

    discriminator.zero_grad()
    d_loss.backward()
    d_optimizer.step()

    # === Train Generator ===
    z = torch.randn(batch_size, noise_dim)
    generated = generator(z)
    g_loss = criterion(discriminator(generated), torch.ones(batch_size, 1))

    generator.zero_grad()
    g_loss.backward()
    g_optimizer.step()

    # Print every 500 epochs
    if epoch % 500 == 0:
        print(f"Epoch {epoch}: D Loss={d_loss.item():.4f}, G Loss={g_loss.item():.4f}")
# Out:
# Epoch 0: D Loss=1.3577, G Loss=0.6576
# Epoch 500: D Loss=0.1475, G Loss=2.2799
# Epoch 1000: D Loss=0.0518, G Loss=4.5132
# Epoch 1500: D Loss=0.0113, G Loss=5.5092
# Epoch 2000: D Loss=0.0022, G Loss=7.3381
# Epoch 2500: D Loss=0.0049, G Loss=8.5562

# %%
num_to_generate = 4900 - 289  # => 4611

# %%
# Number of synthetic samples needed to balance the dataset
num_to_generate = 4900 - 289

# Generate synthetic data using trained Generator
z = torch.randn(num_to_generate, noise_dim)
generated_data = generator(z).detach().numpy()

# Inverse transform back to original scale
generated_original = scaler.inverse_transform(generated_data)

# Convert to DataFrame
synthetic_df = pd.DataFrame(generated_original, columns=X.columns)
synthetic_df['tb_status'] = 0  # Assign minority label

print("Synthetic data shape:", synthetic_df.shape)
# Out:
# Synthetic data shape: (4611, 783)

# %%
# Extract original majority class (tb_status = 1)
majority_df = df[df['tb_status'] == 1]

# Combine with synthetic minority and original minority
minority_df = df[df['tb_status'] == 0]
balanced_df = pd.concat([majority_df, minority_df, synthetic_df], ignore_index=True)

# Shuffle the dataset
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

print("Balanced dataset shape:", balanced_df.shape)
print("Balanced class distribution:\n", balanced_df['tb_status'].value_counts())
# Out:
# Balanced dataset shape: (9800, 783)
# Balanced class distribution:
#  tb_status
# 1    4900
# 0    4900
# Name: count, dtype: int64

# %%
# Save to CSV
balanced_df.to_csv("balanced_tb_data.csv", index=False)
print("Balanced dataset saved as 'balanced_tb_data.csv'")
# Out:
# Balanced dataset saved as 'balanced_tb_data.csv'

# %%
df1 = pd.read_csv("balanced_tb_data.csv")

# %%
import pandas as pd
import numpy as np

# %%
df3 = pd.read_csv("solicited_test_ini.csv")

# %%
df3.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.034994  0.025785 -0.126753 -0.032978 -0.104685 -0.141457  0.080810
# 1 -0.017907  0.014444 -0.149634 -0.028727 -0.092394 -0.137203  0.039822
# 2  0.019554  0.017160 -0.110186 -0.037742 -0.016508 -0.139233  0.051114
# 3 -0.065054  0.040636 -0.175130 -0.022170 -0.118889 -0.120363  0.030802
# 4 -0.042754  0.042994 -0.087392 -0.029497 -0.106971 -0.116307  0.063567
#
#      feat_7    feat_8    feat_9  ...  reported_cough_dur  tb_prior  \
# 0 -0.008430  0.025698 -0.357474  ...                  30        No
# 1 -0.006732  0.037899 -0.338116  ...                  30        No
# 2 -0.017611  0.010689 -0.309711  ...                  30        No
# 3 -0.013428 -0.001530 -0.352130  ...                  30        No
# 4 -0.000677 -0.016347 -0.395569  ...                  14        No
#
#    tb_prior_Pul  hemoptysis  heart_rate  temperature  weight_loss  \
# 0            No          No         102         36.3           No
# 1            No          No         102         36.3           No
# 2            No          No         102         36.3           No
# 3            No          No         102         36.3           No
# 4            No          No          94         36.7           No
#
#    smoke_lweek  fever  night_sweats
# 0           No     No            No
# 1           No     No            No
# 2           No     No            No
# 3           No     No            No
# 4           No    Yes           Yes
#
# [5 rows x 784 columns]
