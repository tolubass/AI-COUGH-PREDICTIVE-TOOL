# %%
import pandas as pd
import numpy as np
import warnings 
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("wav2vec2_embeddings.csv")

# %%
df1 = pd.read_csv("CODA_TB_Clinical_Meta_Info.csv")

# %%
df.head()
# Out:
#                                         filename    feat_0    feat_1  \
# 0  1637846163058-recording-1_modclean_A_seg0.wav -0.026476  0.066998
# 1  1637846163058-recording-1_modclean_B_seg0.wav -0.115683  0.074489
# 2  1637846854303-recording-1_modclean_B_seg0.wav -0.036963  0.027261
# 3  1637846855223-recording-1_modclean_A_seg0.wav -0.066899  0.018125
# 4  1637846855223-recording-1_modclean_B_seg0.wav -0.032680  0.024876
#
#      feat_2    feat_3    feat_4    feat_5    feat_6    feat_7    feat_8  ...  \
# 0 -0.026330 -0.012994 -0.140130 -0.121104  0.082295 -0.000749 -0.034801  ...
# 1  0.014545 -0.005770 -0.184433 -0.109778  0.070073 -0.004235 -0.051047  ...
# 2 -0.097449 -0.025534 -0.055059 -0.135565  0.002773 -0.035429 -0.032010  ...
# 3 -0.133178 -0.038802 -0.032812 -0.119408 -0.008754 -0.031919 -0.104976  ...
# 4 -0.140349 -0.030479  0.017331 -0.111734 -0.022145 -0.028799 -0.051605  ...
#
#    feat_758  feat_759  feat_760  feat_761  feat_762  feat_763  feat_764  \
# ...

# %%
df1.head()
# Out:
#     participant     sex  age  height  weight  reported_cough_dur tb_prior  \
# 0  CODA_TB_0001    Male   27   173.3    63.0                  30       No
# 1  CODA_TB_0002  Female   48   163.0    49.9                  16      Yes
# 2  CODA_TB_0003    Male   51   165.0    58.0                  14      Yes
# 3  CODA_TB_0004    Male   32   166.0    56.0                  90       No
# 4  CODA_TB_0005    Male   28   170.5    53.0                  14       No
#
#   tb_prior_Pul tb_prior_Extrapul tb_prior_Unknown hemoptysis  heart_rate  \
# 0           No                No               No         No          99
# 1          Yes                No               No         No          80
# 2           No               Yes               No         No         100
# 3           No                No               No         No          90
# 4           No                No               No         No          94
#
#    temperature weight_loss smoke_lweek fever night_sweats  tb_status
# ...

# %%
df.columns
# Out:
# Index(['filename', 'feat_0', 'feat_1', 'feat_2', 'feat_3', 'feat_4', 'feat_5',
#        'feat_6', 'feat_7', 'feat_8',
#        ...
#        'feat_758', 'feat_759', 'feat_760', 'feat_761', 'feat_762', 'feat_763',
#        'feat_764', 'feat_765', 'feat_766', 'feat_767'],
#       dtype='object', length=769)

# %%
df1.columns
# Out:
# Index(['participant', 'sex', 'age', 'height', 'weight', 'reported_cough_dur',
#        'tb_prior', 'tb_prior_Pul', 'tb_prior_Extrapul', 'tb_prior_Unknown',
#        'hemoptysis', 'heart_rate', 'temperature', 'weight_loss', 'smoke_lweek',
#        'fever', 'night_sweats', 'tb_status'],
#       dtype='object')
