# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("merged_wav2vec2_clinical.csv")

# %%
df.tail()
# Out:
#         feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 8828 -0.060395  0.053089 -0.076325 -0.032551 -0.033862 -0.120313  0.088492
# 8829 -0.024088  0.029943 -0.104069 -0.046745 -0.010235 -0.108935  0.001636
# 8830 -0.024088  0.029943 -0.104069 -0.046745 -0.010235 -0.108935  0.001636
# 8831 -0.048404  0.009508 -0.033979 -0.045874  0.004356 -0.124104  0.005681
# 8832 -0.048404  0.009508 -0.033979 -0.045874  0.004356 -0.124104  0.005681
#
#         feat_7    feat_8    feat_9  ...  tb_prior_Extrapul  tb_prior_Unknown  \
# 8828 -0.017045  0.021537 -0.373293  ...                 No                No
# 8829 -0.029909 -0.029978 -0.325534  ...                 No                No
# 8830 -0.029909 -0.029978 -0.325534  ...                 No                No
# 8831 -0.018767 -0.101299 -0.348076  ...                 No                No
# 8832 -0.018767 -0.101299 -0.348076  ...                 No                No
#
# ...

# %%
# Display the first 5 rows of selected columns
df[['temperature', 'weight', 'reported_cough_dur', 'smoke_lweek', 'age', 'tb_status']].head()
# Out:
#    temperature  weight  reported_cough_dur smoke_lweek  age  tb_status
# 0         37.5    49.0                  60          No   33          1
# 1         37.5    49.0                  60          No   33          1
# 2         37.5    49.0                  60          No   33          1
# 3         37.5    49.0                  60          No   33          1
# 4         37.7    42.0                 120         Yes   30          1

# %%
# Selected columns
selected_columns = ['temperature', 'weight', 'reported_cough_dur', 'smoke_lweek', 'age', 'tb_status']

# Loop through and print value counts for each column
for col in selected_columns:
    print(f"Value counts for '{col}':\n")
    print(df[col].value_counts(dropna=False))  # dropna=False includes NaN in the count
    print("\n" + "-"*50 + "\n")
# Out:
# Value counts for 'temperature':
#
# temperature
# 36.3    7482
# 37.5     306
# 37.9     275
# 39.1     238
# 37.0     126
# 36.9      99
# 37.8      61
# 36.7      57
# 37.7      56
# 38.5      35
# 36.4      34
# 37.4      20
# 40.1      14
# 37.1      14
# 36.1      11
# 36.5       4
# 36.8       1
# Name: count, dtype: int64
#
# --------------------------------------------------
#
# Value counts for 'weight':
#
# weight
# 53.9    7482
# 48.0     291
# 60.0     275
# 52.5     238
# 61.0      82
# 57.0      69
# 45.5      64
# 69.2      61
# 52.0      57
# 71.0      57
# 42.0      56
# 38.9      35
# 43.0      17
# 41.2      15
# 40.0      13
# 45.0      11
# 49.0       4
# 67.0       4
# 54.0       1
# 45.3       1
# Name: count, dtype: int64
#
# --------------------------------------------------
#
# Value counts for 'reported_cough_dur':
#
# reported_cough_dur
# 35     7482
# 65      275
# 20      272
# 15      257
# 60       87
# 90       69
# 7        61
# 50       57
# ...

# %%
df['tb_status'].value_counts()
# Out:
# tb_status
# 1    8340
# 0     493
# Name: count, dtype: int64

# %%
df['temperature'].value_counts()
# Out:
# temperature
# 36.3    7482
# 37.5     306
# 37.9     275
# 39.1     238
# 37.0     126
# 36.9      99
# 37.8      61
# 36.7      57
# 37.7      56
# 38.5      35
# 36.4      34
# 37.4      20
# 40.1      14
# 37.1      14
# 36.1      11
# 36.5       4
# 36.8       1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 1 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 2 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 3 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 4 -0.036963  0.027261 -0.097449 -0.025534 -0.055059 -0.135565  0.002773
#
#      feat_7    feat_8    feat_9   feat_10   feat_11   feat_12   feat_13  \
# 0 -0.000749 -0.034801 -0.417850  0.080937 -0.128352  0.073134  0.092889
# 1 -0.000749 -0.034801 -0.417850  0.080937 -0.128352  0.073134  0.092889
# 2 -0.004235 -0.051047 -0.439018  0.056775 -0.013347  0.023227  0.076073
# 3 -0.004235 -0.051047 -0.439018  0.056775 -0.013347  0.023227  0.076073
# 4 -0.035429 -0.032010 -0.351857  0.064041 -0.102155  0.065583  0.051239
#
#     feat_14   feat_15   feat_16   feat_17   feat_18   feat_19   feat_20  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(3644)

# %%
# get a dupliacte

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 1 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 2 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 3 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 4 -0.036963  0.027261 -0.097449 -0.025534 -0.055059 -0.135565  0.002773
#
#      feat_7    feat_8    feat_9   feat_10   feat_11   feat_12   feat_13  \
# 0 -0.000749 -0.034801 -0.417850  0.080937 -0.128352  0.073134  0.092889
# 1 -0.000749 -0.034801 -0.417850  0.080937 -0.128352  0.073134  0.092889
# 2 -0.004235 -0.051047 -0.439018  0.056775 -0.013347  0.023227  0.076073
# 3 -0.004235 -0.051047 -0.439018  0.056775 -0.013347  0.023227  0.076073
# 4 -0.035429 -0.032010 -0.351857  0.064041 -0.102155  0.065583  0.051239
#
#     feat_14   feat_15   feat_16   feat_17   feat_18   feat_19   feat_20  \
# ...

# %%
df1 = df1.drop_duplicates()

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
categorical_vars = df1.select_dtypes(include = ['object', 'category']).columns

# %%
categorical_vars
# Out:
# Index(['participant', 'sex', 'tb_prior', 'tb_prior_Pul', 'tb_prior_Extrapul',
#        'tb_prior_Unknown', 'hemoptysis', 'weight_loss', 'smoke_lweek', 'fever',
#        'night_sweats'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# feat_0                0
# feat_1                0
# feat_2                0
# feat_3                0
# feat_4                0
# feat_5                0
# feat_6                0
# feat_7                0
# feat_8                0
# feat_9                0
# feat_10               0
# feat_11               0
# feat_12               0
# feat_13               0
# feat_14               0
# feat_15               0
# feat_16               0
# feat_17               0
# feat_18               0
# feat_19               0
# feat_20               0
# feat_21               0
# feat_22               0
# feat_23               0
# feat_24               0
# feat_25               0
# feat_26               0
# feat_27               0
# feat_28               0
# feat_29               0
# feat_30               0
# feat_31               0
# feat_32               0
# feat_33               0
# feat_34               0
# feat_35               0
# feat_36               0
# feat_37               0
# ...

# %%
categorical_vars = df1.select_dtypes(include=['object', 'category']).columns
for var in categorical_vars:
    print(f"variable: {var}")
    print(f"unique values: {df1[var].nunique()}")
    print("-" *50)
# Out:
# variable: participant
# unique values: 23
# --------------------------------------------------
# variable: sex
# unique values: 2
# --------------------------------------------------
# variable: tb_prior
# unique values: 2
# --------------------------------------------------
# variable: tb_prior_Pul
# unique values: 2
# --------------------------------------------------
# variable: tb_prior_Extrapul
# unique values: 1
# --------------------------------------------------
# variable: tb_prior_Unknown
# unique values: 1
# --------------------------------------------------
# variable: hemoptysis
# unique values: 2
# --------------------------------------------------
# variable: weight_loss
# unique values: 2
# --------------------------------------------------
# variable: smoke_lweek
# unique values: 2
# --------------------------------------------------
# variable: fever
# unique values: 2
# --------------------------------------------------
# variable: night_sweats
# unique values: 2
# ...

# %%
df1['tb_prior_Extrapul'].value_counts()
# Out:
# tb_prior_Extrapul
# No    5189
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 2 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 4 -0.036963  0.027261 -0.097449 -0.025534 -0.055059 -0.135565  0.002773
# 5 -0.066899  0.018125 -0.133178 -0.038802 -0.032812 -0.119408 -0.008754
# 7 -0.032680  0.024876 -0.140349 -0.030479  0.017331 -0.111734 -0.022145
#
#      feat_7    feat_8    feat_9   feat_10   feat_11   feat_12   feat_13  \
# 0 -0.000749 -0.034801 -0.417850  0.080937 -0.128352  0.073134  0.092889
# 2 -0.004235 -0.051047 -0.439018  0.056775 -0.013347  0.023227  0.076073
# 4 -0.035429 -0.032010 -0.351857  0.064041 -0.102155  0.065583  0.051239
# 5 -0.031919 -0.104976 -0.353431  0.062105 -0.068768  0.060031  0.066911
# 7 -0.028799 -0.051605 -0.321307  0.044751 -0.088343  0.082485  0.067815
#
#     feat_14   feat_15   feat_16   feat_17   feat_18   feat_19   feat_20  \
# ...

# %%
df1.columns
# Out:
# Index(['feat_0', 'feat_1', 'feat_2', 'feat_3', 'feat_4', 'feat_5', 'feat_6',
#        'feat_7', 'feat_8', 'feat_9',
#        ...
#        'tb_prior_Extrapul', 'tb_prior_Unknown', 'hemoptysis', 'heart_rate',
#        'temperature', 'weight_loss', 'smoke_lweek', 'fever', 'night_sweats',
#        'tb_status'],
#       dtype='object', length=786)

# %%
df1.drop(columns=["participant"], inplace = True)

# %%
df1.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 2 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 4 -0.036963  0.027261 -0.097449 -0.025534 -0.055059 -0.135565  0.002773
# 5 -0.066899  0.018125 -0.133178 -0.038802 -0.032812 -0.119408 -0.008754
# 7 -0.032680  0.024876 -0.140349 -0.030479  0.017331 -0.111734 -0.022145
#
#      feat_7    feat_8    feat_9   feat_10   feat_11   feat_12   feat_13  \
# 0 -0.000749 -0.034801 -0.417850  0.080937 -0.128352  0.073134  0.092889
# 2 -0.004235 -0.051047 -0.439018  0.056775 -0.013347  0.023227  0.076073
# 4 -0.035429 -0.032010 -0.351857  0.064041 -0.102155  0.065583  0.051239
# 5 -0.031919 -0.104976 -0.353431  0.062105 -0.068768  0.060031  0.066911
# 7 -0.028799 -0.051605 -0.321307  0.044751 -0.088343  0.082485  0.067815
#
#     feat_14   feat_15   feat_16   feat_17   feat_18   feat_19   feat_20  \
# ...

# %%
#df1.columns

# %%
categorical_vars = df1.select_dtypes(include=['object', 'category']).columns

for var in categorical_vars:
    print(f"Variable: {var}")
    print(f"Unique values: {df1[var].nunique()}")
    print("Value Counts:")
    print(df1[var].value_counts())
    print("-" * 50)
# Out:
# Variable: sex
# Unique values: 2
# Value Counts:
# sex
# Male      5052
# Female     137
# Name: count, dtype: int64
# --------------------------------------------------
# Variable: tb_prior
# Unique values: 2
# Value Counts:
# tb_prior
# No     5018
# Yes     171
# Name: count, dtype: int64
# --------------------------------------------------
# Variable: tb_prior_Pul
# Unique values: 2
# Value Counts:
# tb_prior_Pul
# No     5018
# Yes     171
# Name: count, dtype: int64
# --------------------------------------------------
# Variable: tb_prior_Extrapul
# Unique values: 1
# Value Counts:
# tb_prior_Extrapul
# No    5189
# Name: count, dtype: int64
# --------------------------------------------------
# Variable: tb_prior_Unknown
# Unique values: 1
# Value Counts:
# tb_prior_Unknown
# No    5189
# Name: count, dtype: int64
# --------------------------------------------------
# Variable: hemoptysis
# Unique values: 2
# Value Counts:
# hemoptysis
# No     4964
# Yes     225
# ...

# %%
df1.drop(columns=["tb_prior_Extrapul", "tb_prior_Unknown"], inplace = True)

# %%
# encoding the categirical variables

# %%
# Replace 'Male' with 1 and 'Female' with 0
df1['sex'] = df1['sex'].map({'Male': 1, 'Female': 0})

# List of other binary columns to encode (Yes=1, No=0)
binary_columns = [
    'tb_prior', 'tb_prior_Pul','hemoptysis', 'weight_loss', 'smoke_lweek', 'fever', 'night_sweats'
]

# Apply mapping to these columns
for col in binary_columns:
    df1[col] = df1[col].map({'Yes': 1, 'No': 0})

# %%
df1.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.026476  0.066998 -0.026330 -0.012994 -0.140130 -0.121104  0.082295
# 2 -0.115683  0.074489  0.014545 -0.005770 -0.184433 -0.109778  0.070073
# 4 -0.036963  0.027261 -0.097449 -0.025534 -0.055059 -0.135565  0.002773
# 5 -0.066899  0.018125 -0.133178 -0.038802 -0.032812 -0.119408 -0.008754
# 7 -0.032680  0.024876 -0.140349 -0.030479  0.017331 -0.111734 -0.022145
#
#      feat_7    feat_8    feat_9   feat_10   feat_11   feat_12   feat_13  \
# 0 -0.000749 -0.034801 -0.417850  0.080937 -0.128352  0.073134  0.092889
# 2 -0.004235 -0.051047 -0.439018  0.056775 -0.013347  0.023227  0.076073
# 4 -0.035429 -0.032010 -0.351857  0.064041 -0.102155  0.065583  0.051239
# 5 -0.031919 -0.104976 -0.353431  0.062105 -0.068768  0.060031  0.066911
# 7 -0.028799 -0.051605 -0.321307  0.044751 -0.088343  0.082485  0.067815
#
#     feat_14   feat_15   feat_16   feat_17   feat_18   feat_19   feat_20  \
# ...

# %%
df1.to_csv('encoded_clean_clinical_wav2vec2.csv', index = False)

# %%
df1['tb_status'].value_counts()
# Out:
# tb_status
# 1    4900
# 0     289
# Name: count, dtype: int64

# %%
df1.shape
# Out:
# (5189, 783)
